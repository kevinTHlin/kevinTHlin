# %%
import pandas as pd
import numpy as ny

df = pd.read_csv("uwide.csv", sep=",")
df.head(15)
# Out:
#                 USERID  BROWSER_COUNT  COURSE_COUNT  COURSE_LAST_ACCESS  \
# 0   310_20178310080783          334.0            11        1.513620e+09
# 1   310_20178310080790          744.0           407        1.513371e+09
# 2   310_20128310060450           17.0             9        1.505817e+09
# 3   310_20128310320840          154.0           133        1.513881e+09
# 4   310_20128310320777           50.0             1        1.514159e+09
# 5   310_20138310060308          138.0            45        1.514115e+09
# 6   310_20138310320705           54.0             1        1.513362e+09
# 7   310_20138310250134           80.0             7        1.509478e+09
# 8   310_20138310250135          227.0             8        1.509026e+09
# 9   310_20168310450071          238.0          1368        1.513982e+09
# 10  310_20168310450070          402.0          3132        1.513761e+09
# 11  310_20158310100790          178.0           228        1.514912e+09
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2006 entries, 0 to 2005
# Data columns (total 52 columns):
# USERID                         2006 non-null object
# BROWSER_COUNT                  1950 non-null float64
# COURSE_COUNT                   2006 non-null int64
# COURSE_LAST_ACCESS             1950 non-null float64
# COURSE_SUM_VIEW                1327 non-null float64
# COURSE_AVG_SCORE               228 non-null float64
# EXAM_AH_SCORE                  2006 non-null float64
# EXAM_WRITEN_SCORE              2006 non-null float64
# EXAM_MIDDLE_SCORE              2006 non-null float64
# EXAM_LAB                       1468 non-null float64
# EXAM_PROGRESS                  2006 non-null float64
# EXAM_GROUP_SCORE               2006 non-null float64
# EXAM_FACE_SCORE                2006 non-null float64
# EXAM_ONLINE_SCORE              2006 non-null float64
# NODEBB_LAST_POST               750 non-null float64
# NODEBB_CHANNEL_COUNT           750 non-null float64
# ...

# %%
df.columns
df.describe()
# Out:
#        BROWSER_COUNT  COURSE_COUNT  COURSE_LAST_ACCESS  COURSE_SUM_VIEW  \
# count    1950.000000   2006.000000        1.950000e+03      1327.000000
# mean      266.023077   1369.385344        1.513165e+09       477.848950
# std       252.247323   4224.334880        1.393563e+06      2961.198469
# min         3.000000      1.000000        1.503993e+09        -0.015417
# 25%       105.000000     13.000000        1.512395e+09         0.023900
# 50%       190.000000     63.000000        1.513543e+09         0.400961
# 75%       334.750000    495.000000        1.514146e+09         2.282650
# max      2182.000000  71043.000000        1.515064e+09     61494.619641
#
#        COURSE_AVG_SCORE  EXAM_AH_SCORE  EXAM_WRITEN_SCORE  EXAM_MIDDLE_SCORE  \
# count        228.000000    2006.000000        2006.000000        2006.000000
# mean           0.443196      85.837506          10.484416           5.847288
# std            0.218687      11.497755           6.547428           3.880040
# ...

# %%
negative_CSV = df["COURSE_SUM_VIEW"] < 0
print(df[negative_CSV])
# Out:
#                   USERID  BROWSER_COUNT  COURSE_COUNT  COURSE_LAST_ACCESS  \
# 380   310_20148310110298          287.0            21        1.513003e+09
# 624   310_20178310120857         1193.0           190        1.512402e+09
# 674   310_20178310120824          218.0            81        1.514765e+09
# 795   310_20158310030388          135.0            11        1.513861e+09
# 862   310_20158310100778          151.0            24        1.514120e+09
# 1286  310_20158310071464           83.0            84        1.511982e+09
# 1327  310_20178310080751          176.0            44        1.513796e+09
# 1352  310_20158310060579          255.0           243        1.514645e+09
# 1515  310_20178310880120          203.0           154        1.512685e+09
# 1593  310_20168310050648           72.0            36        1.512140e+09
# 1818  310_20168310250005           83.0           128        1.511821e+09
#
#       COURSE_SUM_VIEW  COURSE_AVG_SCORE  EXAM_AH_SCORE  EXAM_WRITEN_SCORE  \
# ...

# %%
df.isnull().any()
# Out:
# USERID                         False
# BROWSER_COUNT                   True
# COURSE_COUNT                   False
# COURSE_LAST_ACCESS              True
# COURSE_SUM_VIEW                 True
# COURSE_AVG_SCORE                True
# EXAM_AH_SCORE                  False
# EXAM_WRITEN_SCORE              False
# EXAM_MIDDLE_SCORE              False
# EXAM_LAB                        True
# EXAM_PROGRESS                  False
# EXAM_GROUP_SCORE               False
# EXAM_FACE_SCORE                False
# EXAM_ONLINE_SCORE              False
# NODEBB_LAST_POST                True
# NODEBB_CHANNEL_COUNT            True
# NODEBB_TOPIC_COUNT              True
# COURSE_SUM_VIDEO_LEN            True
# SEX                            False
# MAJORID                        False
# STATUS                         False
# GRADE                          False
# CLASSID                        False
# EXAM_HOMEWORK                  False
# EXAM_LABSCORE                  False
# ...

# %%
df.isnull().sum()
# Out:
# USERID                            0
# BROWSER_COUNT                    56
# COURSE_COUNT                      0
# COURSE_LAST_ACCESS               56
# COURSE_SUM_VIEW                 679
# COURSE_AVG_SCORE               1778
# EXAM_AH_SCORE                     0
# EXAM_WRITEN_SCORE                 0
# EXAM_MIDDLE_SCORE                 0
# EXAM_LAB                        538
# EXAM_PROGRESS                     0
# EXAM_GROUP_SCORE                  0
# EXAM_FACE_SCORE                   0
# EXAM_ONLINE_SCORE                 0
# NODEBB_LAST_POST               1256
# NODEBB_CHANNEL_COUNT           1256
# NODEBB_TOPIC_COUNT             1256
# COURSE_SUM_VIDEO_LEN              1
# SEX                               0
# MAJORID                           0
# STATUS                            0
# GRADE                             0
# CLASSID                           0
# EXAM_HOMEWORK                     0
# EXAM_LABSCORE                     0
# EXAM_OTHERSCORE                   0
# ...

# %%
BC_null = pd.isnull(df["BROWSER_COUNT"])
df_BC_null = df[BC_null]
print(df_BC_null)
# Out:
#                   USERID  BROWSER_COUNT  COURSE_COUNT  COURSE_LAST_ACCESS  \
# 38    310_20168310100442            NaN            18                 NaN
# 46    310_20168310100452            NaN            18                 NaN
# 50    310_20168310100453            NaN            18                 NaN
# 248   310_20168310090719            NaN           558                 NaN
# 277   310_20168310090714            NaN           740                 NaN
# 294   310_20168310250099            NaN           144                 NaN
# 299   310_20168310250110            NaN          1644                 NaN
# 330   310_20158310020574            NaN            12                 NaN
# 475   310_20158310121056            NaN             9                 NaN
# 523   310_20178310040393            NaN             9                 NaN
# 531   310_20168310370167            NaN            17                 NaN
# 538   310_20168310370186            NaN            17                 NaN
# ...

# %%
New_df = df.dropna(axis=0)
New_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75 entries, 1 to 1971
# Data columns (total 52 columns):
# USERID                         75 non-null object
# BROWSER_COUNT                  75 non-null float64
# COURSE_COUNT                   75 non-null int64
# COURSE_LAST_ACCESS             75 non-null float64
# COURSE_SUM_VIEW                75 non-null float64
# COURSE_AVG_SCORE               75 non-null float64
# EXAM_AH_SCORE                  75 non-null float64
# EXAM_WRITEN_SCORE              75 non-null float64
# EXAM_MIDDLE_SCORE              75 non-null float64
# EXAM_LAB                       75 non-null float64
# EXAM_PROGRESS                  75 non-null float64
# EXAM_GROUP_SCORE               75 non-null float64
# EXAM_FACE_SCORE                75 non-null float64
# EXAM_ONLINE_SCORE              75 non-null float64
# NODEBB_LAST_POST               75 non-null float64
# NODEBB_CHANNEL_COUNT           75 non-null float64
# ...

# %%
New_df_2 = df.dropna(axis=1)
New_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2006 entries, 0 to 2005
# Data columns (total 34 columns):
# USERID                    2006 non-null object
# COURSE_COUNT              2006 non-null int64
# EXAM_AH_SCORE             2006 non-null float64
# EXAM_WRITEN_SCORE         2006 non-null float64
# EXAM_MIDDLE_SCORE         2006 non-null float64
# EXAM_PROGRESS             2006 non-null float64
# EXAM_GROUP_SCORE          2006 non-null float64
# EXAM_FACE_SCORE           2006 non-null float64
# EXAM_ONLINE_SCORE         2006 non-null float64
# SEX                       2006 non-null object
# MAJORID                   2006 non-null object
# STATUS                    2006 non-null object
# GRADE                     2006 non-null int64
# CLASSID                   2006 non-null object
# EXAM_HOMEWORK             2006 non-null float64
# EXAM_LABSCORE             2006 non-null float64
# EXAM_OTHERSCORE           2006 non-null int64
# STUNO                     2006 non-null int64
# ...

# %%
New_data_3 = df[["BROWSER_COUNT", "COURSE_LAST_ACCESS", "COURSE_SUM_VIDEO_LEN", "NODEBB_PARTICIPATIONRATE", "COURSE_WORKTIME", "COURSE_WORKACCURACYRATE", "COURSE_WORKCOMPLETERATE", "NODEBB_POSTSCOUNT", "NODEBB_NORMALBBSPOSTSCOUONT", "NODEBB_REALBBSARCHIVECOUNT", "NORMALBBSARCHIVECOUNT", "COURSE_WORKCOUNT"]].dropna(axis=0)
print(New_data_3)
# Out:
#       BROWSER_COUNT  COURSE_LAST_ACCESS  COURSE_SUM_VIDEO_LEN  \
# 0             334.0        1.513620e+09                   0.0
# 1             744.0        1.513371e+09                   0.0
# 2              17.0        1.505817e+09                   0.0
# 3             154.0        1.513881e+09                1867.0
# 4              50.0        1.514159e+09                   0.0
# ...             ...                 ...                   ...
# 2001          136.0        1.513991e+09                   0.0
# 2002          333.0        1.514234e+09                 356.4
# 2003          110.0        1.514218e+09                   7.5
# 2004          629.0        1.514318e+09                  68.8
# 2005          100.0        1.512167e+09                   0.0
#
#       NODEBB_PARTICIPATIONRATE  COURSE_WORKTIME  COURSE_WORKACCURACYRATE  \
# 0                     9.290000      5430.428571                67.528571
# ...

# %%
New_df_4 = df.dropna(thresh=0.95*len(df), axis=1)
print(New_df_4)
New_df_4 = New_df_4.dropna(axis=0)
print(New_df_4)
# Out:
#                   USERID  BROWSER_COUNT  COURSE_COUNT  COURSE_LAST_ACCESS  \
# 0     310_20178310080783          334.0            11        1.513620e+09
# 1     310_20178310080790          744.0           407        1.513371e+09
# 2     310_20128310060450           17.0             9        1.505817e+09
# 3     310_20128310320840          154.0           133        1.513881e+09
# 4     310_20128310320777           50.0             1        1.514159e+09
# ...                  ...            ...           ...                 ...
# 2001  310_20178310100737          136.0            10        1.513991e+09
# 2002  310_20178310040424          333.0          2561        1.514234e+09
# 2003  310_20158310880546          110.0           187        1.514218e+09
# 2004  310_20178310040418          629.0           312        1.514318e+09
# 2005  310_20178310250002          100.0            12        1.512167e+09
#
#       EXAM_AH_SCORE  EXAM_WRITEN_SCORE  EXAM_MIDDLE_SCORE  EXAM_PROGRESS  \
# ...

# %%
New_df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1950 entries, 0 to 2005
# Data columns (total 46 columns):
# USERID                         1950 non-null object
# BROWSER_COUNT                  1950 non-null float64
# COURSE_COUNT                   1950 non-null int64
# COURSE_LAST_ACCESS             1950 non-null float64
# EXAM_AH_SCORE                  1950 non-null float64
# EXAM_WRITEN_SCORE              1950 non-null float64
# EXAM_MIDDLE_SCORE              1950 non-null float64
# EXAM_PROGRESS                  1950 non-null float64
# EXAM_GROUP_SCORE               1950 non-null float64
# EXAM_FACE_SCORE                1950 non-null float64
# EXAM_ONLINE_SCORE              1950 non-null float64
# COURSE_SUM_VIDEO_LEN           1950 non-null float64
# SEX                            1950 non-null object
# MAJORID                        1950 non-null object
# STATUS                         1950 non-null object
# GRADE                          1950 non-null int64
# ...

# %%
New_df_4.describe()
# Out:
#        BROWSER_COUNT  COURSE_COUNT  COURSE_LAST_ACCESS  EXAM_AH_SCORE  \
# count    1950.000000   1950.000000        1.950000e+03    1950.000000
# mean      266.023077   1401.327692        1.513165e+09      86.690394
# std       252.247323   4276.402732        1.393563e+06       9.896151
# min         3.000000      1.000000        1.503993e+09      18.333333
# 25%       105.000000     14.000000        1.512395e+09      83.500000
# 50%       190.000000     70.000000        1.513543e+09      88.787594
# 75%       334.750000    521.500000        1.514146e+09      93.191667
# max      2182.000000  71043.000000        1.515064e+09      99.666667
#
#        EXAM_WRITEN_SCORE  EXAM_MIDDLE_SCORE  EXAM_PROGRESS  EXAM_GROUP_SCORE  \
# count        1950.000000        1950.000000    1950.000000       1950.000000
# mean           10.558812           5.908947       5.249151          1.537714
# std             6.540453           3.884103      12.629244          1.626306
# ...

# %%
pd.set_option('display.max_columns', 60)
pd.set_option('display.max_rows', 60)
New_df_4.describe()
# Out:
#        BROWSER_COUNT  COURSE_COUNT  COURSE_LAST_ACCESS  EXAM_AH_SCORE  \
# count    1950.000000   1950.000000        1.950000e+03    1950.000000
# mean      266.023077   1401.327692        1.513165e+09      86.690394
# std       252.247323   4276.402732        1.393563e+06       9.896151
# min         3.000000      1.000000        1.503993e+09      18.333333
# 25%       105.000000     14.000000        1.512395e+09      83.500000
# 50%       190.000000     70.000000        1.513543e+09      88.787594
# 75%       334.750000    521.500000        1.514146e+09      93.191667
# max      2182.000000  71043.000000        1.515064e+09      99.666667
#
#        EXAM_WRITEN_SCORE  EXAM_MIDDLE_SCORE  EXAM_PROGRESS  EXAM_GROUP_SCORE  \
# count        1950.000000        1950.000000    1950.000000       1950.000000
# mean           10.558812           5.908947       5.249151          1.537714
# std             6.540453           3.884103      12.629244          1.626306
# ...

# %%
#drop columns referring to variables that obviously have no anything to do with academic success, such as user ID, CLASSID, etc
New_df_4.drop(["USERID", "CLASSID", "STUNO", "ID", "STUID", "COURSEOPENID", "STUDYTERM", "COURSEID", "EXAMNUM", "PROCESS", "MAJORID", "STATUS", "GRADE", "GROUPSTUDYSCORE", "OTHERSCORE", "LABSCORE", "WRITTENASSIGNMENTSCORE", "COURSE_LAST_ACCESS", "EXAM_OTHERSCORE", "COURSE_WORKTIME", "NORMALBBSARCHIVECOUNT"], axis=1, inplace=True)

# %%
print(New_df_4)
# Out:
#       BROWSER_COUNT  COURSE_COUNT  EXAM_AH_SCORE  EXAM_WRITEN_SCORE  \
# 0             334.0            11      94.000000           2.727273
# 1             744.0           407      91.454545           2.727273
# 2              17.0             9      54.166667           6.166667
# 3             154.0           133      81.000000           0.000000
# 4              50.0             1      67.000000           0.000000
# ...             ...           ...            ...                ...
# 2001          136.0            10      60.600000           2.700000
# 2002          333.0          2561      97.916667           2.500000
# 2003          110.0           187      78.375000           5.625000
# 2004          629.0           312      94.333333           2.416667
# 2005          100.0            12      92.000000           9.818182
#
#       EXAM_MIDDLE_SCORE  EXAM_PROGRESS  EXAM_GROUP_SCORE  EXAM_FACE_SCORE  \
# 0              1.727273       0.000000          0.000000        10.450000
# ...
